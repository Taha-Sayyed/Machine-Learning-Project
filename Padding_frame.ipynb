# %% [markdown]
# <a href="https://colab.research.google.com/github/Taha-Sayyed/Machine-Learning-Project/blob/main/Padding_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt

# %%
def padding():
  img=cv.imread("/content/drive/MyDrive/Face_Recognition/taha.jpg")
  imgRGB=cv.cvtColor(img,cv.COLOR_BGR2RGB)

  pad =300

  borderTypes=[cv.BORDER_CONSTANT,cv.BORDER_REFLECT,cv.BORDER_REPLICATE,cv.BORDER_WRAP]
  borderTitles=['constants','reflect','replicate','wrap']

  plt.figure()
  plt.subplot(231)
  plt.imshow(imgRGB)
  plt.title('Original')

  for i in range(len(borderTypes)):
    plt.subplot(2,3,i+2)
    plt.imshow(cv.copyMakeBorder(imgRGB,pad,pad,pad,pad,borderTypes[i]))
    plt.title(borderTitles[i])

  plt.show()

# %%
if __name__ == '__main__':
  padding()

# %%
def padding():
  img=cv.imread("/content/drive/MyDrive/Face_Recognition/taha.jpg")
  imgRGB=cv.cvtColor(img,cv.COLOR_BGR2RGB)
  pad=300

  borderType=cv.BORDER_CONSTANT
  borderTitle='Constant'
  plt.figure()
  plt.subplot(121)
  plt.imshow(imgRGB)
  plt.title('Original')

  plt.subplot(122)
  plt.imshow(cv.copyMakeBorder(imgRGB,pad,pad,pad,pad,borderType))
  plt.title(borderTitle)

  plt.show()

# %%
if __name__ == '__main__':
  padding()
