# %% [markdown]
# <a href="https://colab.research.google.com/github/Taha-Sayyed/Machine-Learning-Project/blob/main/detect_single_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn opencv-python-headless
# Out:
# Collecting mtcnn
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from mtcnn) (1.4.2)
# Collecting lz4>=4.3.3 (from mtcnn)
#   Downloading lz4-4.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (1.26.4)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.1 MB/s eta 0:00:00
# Downloading lz4-4.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.3 MB/s eta 0:00:00
# Installing collected packages: lz4, mtcnn
# Successfully installed lz4-4.4.3 mtcnn-1.0.0

# %%
import cv2

# %%
import os
print(os.listdir("/content/"))  # Should show 'taha.png'
# Out:
# ['.config', 'taha.png', 'sample_data']

# %%
img = cv2.imread("/content/taha.png")

# %%
from mtcnn import MTCNN
import cv2

# Initialize face detector
detector = MTCNN()

# Read image
img = cv2.imread("taha.png")

# Check if image is loaded properly
if img is None:
    print("Error: Image not found or unable to read.")
else:
    # Perform face detection
    output = detector.detect_faces(img)
    print(output)
# Out:
# [{'box': [245, 197, 157, 178], 'confidence': 0.9999997615814209, 'keypoints': {'nose': [327, 297], 'mouth_right': [360, 330], 'right_eye': [363, 263], 'left_eye': [289, 263], 'mouth_left': [292, 330]}}]

# %%
x,y,width,height= output[0]['box']

# %%
cv2.rectangle(img,pt1=(x,y),pt2=(x+width,y+height),color=(255,0,0),thickness=3)
# Out:
# array([[[ 47,  90,  56],
#         [ 56, 104,  68],
#         [ 66, 120,  82],
#         ...,
#         [ 62, 106,  60],
#         [ 47,  96,  48],
#         [ 35,  90,  40]],
#
#        [[ 47,  92,  56],
#         [ 57, 106,  69],
#         [ 69, 122,  83],
#         ...,
#         [ 51,  92,  46],
#         [ 37,  81,  34],
#         [ 26,  76,  26]],
#
#        [[ 49,  95,  59],
#         [ 61, 110,  72],
#         [ 75, 127,  88],
#         ...,
#         [ 45,  84,  39],
#         [ 36,  77,  30],
#         [ 28,  72,  24]],
#
#        ...,
#
#        [[ 76,  95, 112],
#         [ 67,  84, 102],
#         [ 61,  77,  95],
#         ...,
#         [ 24,  37,  25],
#         [ 32,  47,  36],
#         [ 22,  41,  28]],
#
#        [[ 77,  96, 113],
#         [ 68,  85, 102],
#         [ 61,  77,  95],
#         ...,
#         [ 27,  36,  27],
#         [ 30,  41,  32],
#         [ 22,  38,  27]],
#
#        [[ 78,  96, 113],
#         [ 68,  86, 103],
#         [ 62,  78,  95],
#         ...,
#         [ 31,  35,  28],
#         [ 27,  35,  27],
#         [ 20,  33,  24]]], dtype=uint8)
