# %% [markdown]
# <a href="https://colab.research.google.com/github/Taha-Sayyed/Machine-Learning-Project/blob/main/basic_function_OpenCv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1️⃣ Gray Image 🏳️
# ->Converts a color image to grayscale (black & white) by removing color information.
#
# 2️⃣ Blur Image 🔄
# ->Applies a smoothing effect using Gaussian blur to reduce noise and details.
#
# 3️⃣ Canny Image ⚡
# ->Detects edges in an image by identifying areas with high intensity changes.
#
# 4️⃣ Dilation Image 📏
# ->Expands white regions (edges) to make them thicker, useful for highlighting edges.
#
# 5️⃣ Eroded Image 🧽
# ->Shrinks white regions, removing noise and disconnecting small details.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/taha.png")

# %%
kernel=np.ones((5,5),np.uint8)

# %%
imgGray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
imgBlur=cv2.GaussianBlur(imgGray,(7,7),0)
imgCanny=cv2.Canny(img,150,200)
imgDialation=cv2.dilate(imgCanny,kernel,iterations=1) #iteration decide the thinkness of the edge
imgEroded=cv2.erode(imgDialation,kernel,iterations=1)

# %%
cv2_imshow(imgGray)
# Out:
# <PIL.Image.Image image mode=L size=631x626>

# %%
cv2_imshow(imgBlur)
# Out:
# <PIL.Image.Image image mode=L size=631x626>

# %%
cv2_imshow(imgCanny)
# Out:
# <PIL.Image.Image image mode=L size=631x626>

# %%
cv2_imshow(imgDialation)
# Out:
# <PIL.Image.Image image mode=L size=631x626>

# %%
cv2_imshow(imgEroded)
# Out:
# <PIL.Image.Image image mode=L size=631x626>
