# %% [markdown]
# <a href="https://colab.research.google.com/github/Taha-Sayyed/Machine-Learning-Project/blob/main/Resizing_cropping_OpenCv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# # OpenCv Convention

# %%
img_1 = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Convention.png")

# %%
cv2_imshow(img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=1130x609>

# %% [markdown]
# # Resizing

# %%
img_2=cv2.imread("/content/drive/MyDrive/Colab Notebooks/taha.png")

# %%
cv2_imshow(img_2)
print(img_2.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=631x626>
# (626, 631, 3)

# %% [markdown]
# 626 → Height (rows)
#
# 631 → Width (columns)
#
# 3 → Number of color channels (Blue, Green, Red)

# %%
img_2_resize=cv2.resize(img_2,(200,200))
cv2_imshow(img_2_resize)
print(img_2_resize.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
# (200, 200, 3)

# %% [markdown]
# # Cropping

# %%
img_2_cropped=img_2[80:500,0:631]
cv2_imshow(img_2_cropped)
print(img_2_cropped.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=631x420>
# (420, 631, 3)
